# %%
from datetime import datetime
name = "Anna-Maria"
location = "Oslo"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Anna-Maria start programming at 2023-12-27 19:15:08.824276. Oslo is the best city!

# %% [markdown]
# sth new
